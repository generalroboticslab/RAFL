# %% [markdown]
# Measurement99: 150g
# Measurement101: 200g
# Measurement103: 220g
# Measurement105: 240g
# Measurement107: 170g
# Measurement109: 120g
# Measurement111: 100g
# Measurement113: 110g
# Measurement115: 130g? 80?
# Measurement117: 140g
# Measurement119: 250g
# <!-- Measurement121: 270g -->
# Measurement123: 300g
# ### More static
# Measurement125: 160g
# Measurement127: 190g
# Measurement129: 270g #almost tip
# Measurement131: 320g #almost tip
# Measurement133: 350g #0.6cm
# Measurement7: 100g #almost tip
# Measurement2: 120g #almost tip
# Measurement4: 140g #almost tip
# Measurement6: 150g #almost tip
# Measurement8: 170g #
#
# #############Base is moved##########
# Measurement10: 200g
# Measurement12: 220g
# Measurement14: 250g
# Measurement16: 270g
# Measurement18: 50g
# Measurement20: 300g #0.9cm
# Measurement22: 70g
# Measurement24: 110g
# Measurement26: 130g
# Measurement30: 160g
# Measurement32: 140g
# Measurement34: 210g
# Measurement36: 230g
# Measurement38: 240g
# Measurement40: 60g
# Measurement42: 260g
# Measurement44: 80g
# Measurement46: 40g

# %% [markdown]
# Markers:
# 1.5cm, 2.8cm
# 0.06cm, 2.8cm
# 1.5cm, 2.8cm
#
# 0.06cm, 4.9cm
# 1.5cm, 4.9cm
# 1.5cm, 4.9cm
#
# 7.3cm

# %%
from scipy import io
import numpy as np
import matplotlib.pyplot as plt

filename = 'Measurement46.mat' #12,24
q0 = io.loadmat(filename)
search = 'Measurement'
Measurement = [key for key in q0.keys() if search in key]
# x0 = q0[Measurement[0]]
x0 = q0[Measurement[0]][0][0][5][0][0][1][0][0][1][3,1,400:1500]
steady = q0[Measurement[0]][0][0][5][0][0][1][0][0][1][:,:3, -1]
print(steady)

filename = 'Measurement44.mat' #12,24
q0 = io.loadmat(filename)
search = 'Measurement'
Measurement = [key for key in q0.keys() if search in key]
# x0 = q0[Measurement[0]]
x0 = q0[Measurement[0]][0][0][5][0][0][1][0][0][1][3,1,400:1500]
steady = q0[Measurement[0]][0][0][5][0][0][1][0][0][1][:,:3, -1]
print(steady)
# plt.plot(x0)
# Out:
# [[  68.24946579 -204.80268593  -28.46564044]
#  [  45.84006594 -226.43318016   -9.60220996]
#  [  24.74235786 -222.95709624  -31.10121551]
#  [  67.88458414 -225.8969352   -39.3804068 ]
#  [          nan           nan           nan]
#  [  48.47461188 -201.54243245  -49.39518319]
#  [  29.53498587 -200.60374924  -20.09409778]
#  [  65.15635048 -248.06601081  -32.17030174]
#  [  22.884482   -244.99176475  -32.73107332]
#  [  33.94579135 -248.43146814  -12.20072639]
#  [   4.32427193  -13.60726801  612.88578675]
#  [  53.18294638 -245.02965536  -54.11687019]]
# [[  65.18618487 -248.05539794  -32.32927022]
#  [  33.89394297 -248.45125828  -12.29904587]
#  [  67.91440149 -225.82590706  -39.41976248]
#  [  24.71951459 -222.94294824  -31.18471728]
#  [  53.11176716 -244.98663813  -54.38962348]
#  [  29.47610341 -200.61008621  -20.08671785]
#  [          nan           nan           nan]
#  [  45.81201201 -226.44656239   -9.71864929]
#  [  23.06986686 -245.09722967  -32.8849228 ]
# ...

# %%
# print(x[:,:3,-1])
x = q0[Measurement[0]][0][0][5][0][0][1][0][0][1]
from mpl_toolkits import mplot3d
import numpy as np
from matplotlib import pyplot
import matplotlib.pyplot as plt
from pylab import figure
 
beam = x[:, :3, -1]
print(beam)
# Creating dataset
# z = np.random.randint(100, size =(50))
# x = np.random.randint(80, size =(50))
# y = np.random.randint(60, size =(50))
# print(x.shape)
# ind = [0,1,2,3,5,6,7,8,9,11]
# x = beam[ind, 0]
# y = beam[ind, 1]
# z = beam[ind, 2]
# beam[10,2] = 200
x = beam[:,0]
print(x.shape)
y = beam[:,1]
z = beam[:,2]

# Creating figure
# fig = plt.figure(figsize = (10, 7))
# ax = plt.axes(projection ="3d")
 
# Creating plot
# ax.scatter3D(x, y, z, color = "green")
fig = figure()
ax = fig.add_subplot(projection='3d')

for i in range(len(beam)): #plot each point + it's index as text above
    ax.scatter(beam[i,0],beam[i,1],beam[i,2],color='b') 
    ax.text(beam[i,0],beam[i,1],beam[i,2],  '%s' % (str(i)), size=20, zorder=1,  
    color='k') 
ax.set_xlabel('x')
ax.set_ylabel('y')
ax.set_zlabel('z')
plt.title("simple 3D scatter plot")
 
# show plot
plt.show()
# Out:
# posx and posy should be finite values
# posx and posy should be finite values
# [[  68.24946579 -204.80268593  -28.46564044]
#  [  45.84006594 -226.43318016   -9.60220996]
#  [  24.74235786 -222.95709624  -31.10121551]
#  [  67.88458414 -225.8969352   -39.3804068 ]
#  [          nan           nan           nan]
#  [  48.47461188 -201.54243245  -49.39518319]
#  [  29.53498587 -200.60374924  -20.09409778]
#  [  65.15635048 -248.06601081  -32.17030174]
#  [  22.884482   -244.99176475  -32.73107332]
#  [  33.94579135 -248.43146814  -12.20072639]
#  [   4.32427193  -13.60726801  612.88578675]
#  [  53.18294638 -245.02965536  -54.11687019]]
# (12,)

# %%
from scipy import io
import numpy as np
import matplotlib.pyplot as plt

filename = 'Measurement14.mat' #12,24
q0 = io.loadmat(filename)
search = 'Measurement'
Measurement = [key for key in q0.keys() if search in key]
# x0 = q0[Measurement[0]]
x0 = q0[Measurement[0]][0][0][5][0][0][1][0][0][1][3,1,400:1000]
x = q0[Measurement[0]][0][0][5][0][0][1][0][0][1]
# plt.plot(x0)
x = q0[Measurement[0]][0][0][5][0][0][1][0][0][1]
from mpl_toolkits import mplot3d
import numpy as np
from matplotlib import pyplot
import matplotlib.pyplot as plt
from pylab import figure
 
beam = x[:, :3, -1]
print(beam)
# Creating dataset
# z = np.random.randint(100, size =(50))
# x = np.random.randint(80, size =(50))
# y = np.random.randint(60, size =(50))
# print(x.shape)
# ind = [0,1,2,3,5,6,7,8,9,11]
# x = beam[ind, 0]
# y = beam[ind, 1]
# z = beam[ind, 2]
beam[10,2] = 200
x = beam[:,0]
print(x.shape)
y = beam[:,1]
z = beam[:,2]

# Creating figure
# fig = plt.figure(figsize = (10, 7))
# ax = plt.axes(projection ="3d")
 
# Creating plot
# ax.scatter3D(x, y, z, color = "green")
fig = figure()
ax = fig.add_subplot(projection='3d')

for i in range(len(beam)): #plot each point + it's index as text above
    ax.scatter(beam[i,0],beam[i,1],beam[i,2],color='b') 
    ax.text(beam[i,0],beam[i,1],beam[i,2],  '%s' % (str(i)), size=20, zorder=1,  
    color='k') 
ax.set_xlabel('x')
ax.set_ylabel('y')
ax.set_zlabel('z')
plt.title("simple 3D scatter plot")
 
# show plot
plt.show()
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# File ~/miniconda3/envs/diff_pd/lib/python3.8/site-packages/scipy/io/matlab/mio.py:39, in _open_file(file_like, appendmat, mode)
#      38 try:
# ---> 39     return open(file_like, mode), True
#      40 except IOError:
#      41     # Probably "not found"
#
# FileNotFoundError: [Errno 2] No such file or directory: 'Measurement14.mat'
#
# During handling of the above exception, another exception occurred:
#
# FileNotFoundError                         Traceback (most recent call last)
# Cell In [15], line 6
#       3 import matplotlib.pyplot as plt
#       5 filename = 'Measurement14.mat' #12,24
# ----> 6 q0 = io.loadmat(filename)
#       7 search = 'Measurement'
#       8 Measurement = [key for key in q0.keys() if search in key]
#
# ...

# %%
from time import sleep


for i in range(12):
    if i == 0 or i == 6:
        continue
    for j in range(3):
        x0 = x[i, j, 400:1000]
        plt.plot(x0)
        plt.title(f"{i} marker, {j} axis")
        plt.figure()
        sleep(0.1)
# Out:
# /tmp/ipykernel_148790/1629358696.py:11: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
#   plt.figure()
# /tmp/ipykernel_148790/1629358696.py:11: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
#   plt.figure()
# /tmp/ipykernel_148790/1629358696.py:11: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
#   plt.figure()
# ...
